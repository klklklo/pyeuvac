# %%
! python3 -m pip install pyeuvac
# Out:
# Collecting pyeuvac
#   Downloading pyeuvac-0.1.0b0-py3-none-any.whl.metadata (780 bytes)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from pyeuvac) (6.5.2)
# Collecting netcdf4 (from pyeuvac)
#   Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyeuvac) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pyeuvac) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pyeuvac) (2025.12.0)
# Collecting sparse (from pyeuvac)
#   Downloading sparse-0.18.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting cftime (from netcdf4->pyeuvac)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4->pyeuvac) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pyeuvac) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pyeuvac) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pyeuvac) (2025.3)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.12/dist-packages (from sparse->pyeuvac) (0.60.0)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from xarray->pyeuvac) (26.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.49->sparse->pyeuvac) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pyeuvac) (1.17.0)
# Downloading pyeuvac-0.1.0b0-py3-none-any.whl (9.7 kB)
# Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 25.2 MB/s eta 0:00:00
# Downloading sparse-0.18.0-py2.py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 5.7 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: cftime, sparse, netcdf4, pyeuvac
# Successfully installed cftime-1.6.5 netcdf4-1.7.4 pyeuvac-0.1.0b0 sparse-0.18.0

# %%
# (1) Importing the EUVAC model into the current namespace
from pyeuvac import Euvac

# (2) Creating an instance of the EUVAC model
euvac = Euvac()

# (3) Calculating spectral bands
bands, lines = euvac.get_spectra(f107=[200, 210], f107avg=[200, 210])

# %%
# (4) --
print(lines)
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:           (F107: 2, F107AVG: 2, line_wavelength: 17, line_number: 17)
# Coordinates:
#   * F107              (F107) float64 16B 200.0 210.0
#   * F107AVG           (F107AVG) float64 16B 200.0 210.0
#   * line_wavelength   (line_wavelength) float64 136B 25.63 28.41 ... 102.6 103.2
#   * line_number       (line_number) int64 136B 0 1 2 3 4 5 ... 11 12 13 14 15 16
# Data variables:
#     euv_flux_spectra  (F107, F107AVG, line_wavelength) float64 1kB <COO: nnz=34, fill_value=0.0>
#     wavelength        (line_number) float64 136B 25.63 28.41 ... 102.6 103.2
# Attributes:
#     F10.7 units:                 10^-22 · W · m^-2 · Hz^-1
#     F10.7 81-day average units:  10^-22 · W · m^-2 · Hz^-1
#     spectrum units:              photons · m^-2 · s^-1
#     wavelength units:            nm
#     euv_flux_spectra:            modeled EUV solar irradiance
#     wavelength:                  the wavelength of a discrete line

# %%
# (5) --
print(bands)
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:           (F107: 2, F107AVG: 2, band_center: 20, band_number: 20)
# Coordinates:
#   * F107              (F107) float64 16B 200.0 210.0
#   * F107AVG           (F107AVG) float64 16B 200.0 210.0
#   * band_center       (band_center) float64 160B 7.5 12.5 17.5 ... 97.5 102.5
#   * band_number       (band_number) int64 160B 0 1 2 3 4 5 ... 14 15 16 17 18 19
# Data variables:
#     euv_flux_spectra  (F107, F107AVG, band_center) float64 1kB <COO: nnz=40, fill_value=0.0>
# Attributes:
#     F10.7 units:                 10^-22 · W · m^-2 · Hz^-1
#     F10.7 81-day average units:  10^-22 · W · m^-2 · Hz^-1
#     spectrum units:              photons · m^-2 · s^-1
#     wavelength units:            nm
#     euv_flux_spectra:            modeled EUV solar irradiance
#     lband:                       lower boundary of wavelength interval
#     uband:                       upper boundary of wavelength interval

# %%
# (6) Importing modules required to preprocess and plot EUV-bands
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()

# (7) Taking wavelength intervals and a flux as numpy arrays
lband = bands['lband'].to_numpy()
uband = bands['uband'].to_numpy()
euv_flux = bands['euv_flux_spectra'].to_numpy()

# (8) Converting the euv_flux array to 1D
#     for passing it to the plotting routine
euv_flux = euv_flux.flatten()

# (9) Making an array holding coordinates of all 'edges'
spectrum_edges = np.hstack([lband, uband[-1]])

# (10) --
plt.xlabel(r'Wavelength $\lambda$, $[nm]$')
plt.xticks(spectrum_edges, rotation=35)
plt.ylabel(r'Flux density $N_\lambda$ , $[m^{-2} \cdot s^{-1}]$')
plt.stairs(values=euv_flux, edges=spectrum_edges, fill=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1230         try:
# -> 1231             variable = self._variables[name]
#    1232         except KeyError:
#
# KeyError: 'lband'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1337             try:
# -> 1338                 return self._construct_dataarray(key)
#    1339             except KeyError as e:
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1232         except KeyError:
# -> 1233             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1234
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset_utils.py in _get_virtual_variable(variables, key, dim_sizes)
#      78     if len(split_key) != 2:
# ---> 79         raise KeyError(key)
#      80
#
# KeyError: 'lband'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_355/1081545228.py in <cell line: 0>()
#       5
#       6 # (7) Taking wavelength intervals and a flux as numpy arrays
# ----> 7 lband = bands['lband'].to_numpy()
#       8 uband = bands['uband'].to_numpy()
#       9 euv_flux = bands['euv_flux_spectra'].to_numpy()
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1349                 if isinstance(key, tuple):
#    1350                     message += f"\nHint: use a list to select multiple variables, for example `ds[{list(key)}]`"
# -> 1351                 raise KeyError(message) from e
#    1352
#    1353         if utils.iterable_of_hashable(key):
#
# KeyError: "No variable named 'lband'. Variables on the dataset include ['euv_flux_spectra', 'F107', 'F107AVG', 'band_center', 'band_number']"
